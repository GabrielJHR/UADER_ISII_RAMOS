# %% [markdown]
# # Trabajo Práctico N° 3

# %% [markdown]
# 1.

# %%
pi = 3.14
print("Es el primer bloque del proyecto")
# Out:
# Es el primer bloque del proyecto

# %%
print("Es el segundo bloque del proyecto", pi * 2)
# Out:
# Es el segundo bloque del proyecto 6.28

# %% [markdown]
# 6.
# * Restart elimina todas las variables de l memoria
# * Restart & clear: hace lo mismo que restart pero tambien elimina los resultados mostrados en las celdas.
# * Interrupt interrumpe la ejecucion de una celda

# %% [markdown]
# 7. In[numero] indentifica la celda por lo tanto ese identificador es unico

# %% [markdown]
# # Universidad Autónoma de Entre Ríos
# ## Facultad de Ciencia y Tecnología
# ### Sede Concepción del Uruguay
# Licenciatura en Sistema de Información:
# - Primer año
# - Segundo año
# - **Tercer** año
# - Cuarto año
# - Quinto año

# %% [markdown]
# **Imagen desde internet**

# %% [markdown]
# ![Imagen](https://programacion.net/files/article/20170717020730_python-logo.png)

# %% [markdown]
# **Imagen desde la PC**

# %% [markdown]
# ![jupyter logo](img/logo.png)
